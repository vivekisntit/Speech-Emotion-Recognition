# %%
import pandas as pd

# %%
df=pd.read_csv("../data/processed/metadata.csv")

# %%
df["emotion"].value_counts()
# Out:
# emotion
# angry       1923
# sad         1923
# fear        1923
# happy       1923
# disgust     1923
# neutral     1703
# surprise     652
# calm         192
# Name: count, dtype: int64
